# %% [markdown]
# Proceso de consolidación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 2018

# %% [markdown]
# ### VIOLENCIA INTRAFAMILIAR

# %%
# Violencia intrafamiliar 2024

url = 'https://www.policia.gov.co/sites/default/files/delitos-impacto/violencia_intrafamiliar_2018_0.xlsx'
df_violencia_intra2024 = pd.read_excel(url, header=10)
df_violencia_intra2024 = df_violencia_intra2024.iloc[:-6]
df_violencia_intra2024['TIPO_DELITO'] = 'VIOLENCIA INTRAFAMILIAR'
display(df_violencia_intra2024.head())
# Out:
#   DEPARTAMENTO     MUNICIPIO  CODIGO DANE                 ARMAS MEDIOS  \
# 0     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 1     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 2     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 3     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 4     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
#
#   FECHA HECHO     GENERO *AGRUPA EDAD PERSONA  CANTIDAD  \
# 0  2018-02-11   FEMENINO              ADULTOS       1.0
# 1  2018-02-11  MASCULINO              ADULTOS       1.0
# 2  2018-03-02   FEMENINO              ADULTOS       1.0
# 3  2018-03-11  MASCULINO              ADULTOS       1.0
# 4  2018-05-27  MASCULINO              ADULTOS       1.0
#
#                TIPO_DELITO
# 0  VIOLENCIA INTRAFAMILIAR
# 1  VIOLENCIA INTRAFAMILIAR
# 2  VIOLENCIA INTRAFAMILIAR
# 3  VIOLENCIA INTRAFAMILIAR
# 4  VIOLENCIA INTRAFAMILIAR

# %% [markdown]
# ### SECUESTRO

# %%
# Secuestro
url = 'https://www.policia.gov.co/sites/default/files/delitos-impacto/secuestro_2018_3.xlsx'
df_secuestro2024 = pd.read_excel(url, header=10)
df_secuestro2024 = df_secuestro2024.iloc[:-6]
df_secuestro2024['TIPO_DELITO'] = 'SECUESTRO'
display(df_secuestro2024.head())
# Out:
#    DEPARTAMENTO            MUNICIPIO  CODIGO DANE  \
# 0     ANTIOQUIA        MEDELLÍN (CT)    5001000.0
# 1        CALDAS              ANSERMA   17042000.0
# 2         CAUCA           VILLA RICA   19845000.0
# 3         CHOCÓ  EL CARMEN DE ATRATO   27245000.0
# 4  CUNDINAMARCA     BOGOTÁ D.C. (CT)   11001000.0
#
#                   ARMAS MEDIOS FECHA HECHO     GENERO AGRUPA EDAD PERSONA  \
# 0  ARMA BLANCA / CORTOPUNZANTE  2018-03-17  MASCULINO        ADOLESCENTES
# 1  ARMA BLANCA / CORTOPUNZANTE  2018-01-07   FEMENINO             ADULTOS
# 2  ARMA BLANCA / CORTOPUNZANTE  2018-04-09  MASCULINO             ADULTOS
# 3  ARMA BLANCA / CORTOPUNZANTE  2018-01-26  MASCULINO             ADULTOS
# 4  ARMA BLANCA / CORTOPUNZANTE  2018-04-22  MASCULINO             MENORES
#
#              DESCRIPCION CONDUCTA  CANTIDAD TIPO_DELITO
# 0  ARTÍCULO 168. SECUESTRO SIMPLE       1.0   SECUESTRO
# 1  ARTÍCULO 168. SECUESTRO SIMPLE       1.0   SECUESTRO
# ...

# %% [markdown]
# ### AMENAZAS

# %%
# Amenazas 2024

url = 'https://www.policia.gov.co/sites/default/files/delitos-impacto/amenazas_2018_1.xlsx'
df_amenazas2024 = pd.read_excel(url, header=10)
df_amenazas2024 = df_amenazas2024.iloc[:-6]
df_amenazas2024['TIPO_DELITO'] = 'AMENAZAS'
display(df_amenazas2024.head())
# Out:
#   DEPARTAMENTO     MUNICIPIO  CODIGO DANE                 ARMAS MEDIOS  \
# 0     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 1     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 2     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 3     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 4     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
#
#   FECHA HECHO     GENERO AGRUPA EDAD PERSONA  CANTIDAD TIPO_DELITO
# 0  2018-01-02  MASCULINO             ADULTOS       1.0    AMENAZAS
# 1  2018-01-20   FEMENINO             ADULTOS       1.0    AMENAZAS
# 2  2018-01-20  MASCULINO        ADOLESCENTES       1.0    AMENAZAS
# 3  2018-03-27  MASCULINO             ADULTOS       1.0    AMENAZAS
# 4  2018-03-30  MASCULINO             ADULTOS       1.0    AMENAZAS

# %% [markdown]
# ### EXTORSIÓN

# %%
# Extorsión 2024

url = 'https://www.policia.gov.co/sites/default/files/delitos-impacto/extorsion_2018_3.xlsx'
df_extorsion2024 = pd.read_excel(url, header=9)
df_extorsion2024 = df_extorsion2024.iloc[:-6]
df_extorsion2024['TIPO_DELITO'] = 'EXTORSIÓN'
display(df_extorsion2024.head())
# Out:
#   DEPARTAMENTO MUNICIPIO  CODIGO DANE     ARMAS MEDIOS FECHA HECHO     GENERO  \
# 0    ANTIOQUIA     ANORÍ    5040000.0  CARTA EXTORSIVA  2018-06-17  MASCULINO
# 1    ANTIOQUIA     ANORÍ    5040000.0  CARTA EXTORSIVA  2018-10-15  MASCULINO
# 2    ANTIOQUIA     BELLO    5088000.0  CARTA EXTORSIVA  2018-06-12  MASCULINO
# 3    ANTIOQUIA     BELLO    5088000.0  CARTA EXTORSIVA  2018-09-13  MASCULINO
# 4    ANTIOQUIA     BELLO    5088000.0  CARTA EXTORSIVA  2018-12-23  MASCULINO
#
#   *AGRUPA EDAD PERSONA  CANTIDAD TIPO_DELITO
# 0              ADULTOS       1.0   EXTORSIÓN
# 1              ADULTOS       1.0   EXTORSIÓN
# 2              ADULTOS       1.0   EXTORSIÓN
# 3              ADULTOS       1.0   EXTORSIÓN
# 4              ADULTOS       1.0   EXTORSIÓN

# %% [markdown]
# ### LESIONES TRÁNSITO

# %%
# Lesiones en accidente de tránsito 2024

url = 'https://www.policia.gov.co/sites/default/files/delitos-impacto/lesiones_en_accidente_de_transito_2018_0.xlsx'
df_lesiones_transito2024 = pd.read_excel(url, header=10)
df_lesiones_transito2024 = df_lesiones_transito2024.iloc[:-6]
df_lesiones_transito2024['TIPO_DELITO'] = 'LESIONES EN ACCIDENTE DE TRÁNSITO'
display(df_lesiones_transito2024.head())
# Out:
#    DEPARTAMENTO   MUNICIPIO  CODIGO DANE FECHA HECHO     GENERO  \
# 0  CUNDINAMARCA   ZIPAQUIRÁ   25899000.0  2018-01-01   FEMENINO
# 1         CAUCA     CALDONO   19137000.0  2018-01-01  MASCULINO
# 2     ANTIOQUIA       BELLO    5088000.0  2018-01-01   FEMENINO
# 3     ANTIOQUIA  COPACABANA    5212000.0  2018-01-01   FEMENINO
# 4     ANTIOQUIA  COPACABANA    5212000.0  2018-01-01  MASCULINO
#
#   AGRUPA EDAD PERSONA  CANTIDAD                        TIPO_DELITO
# 0             ADULTOS       1.0  LESIONES EN ACCIDENTE DE TRÁNSITO
# 1             ADULTOS       1.0  LESIONES EN ACCIDENTE DE TRÁNSITO
# 2             ADULTOS       1.0  LESIONES EN ACCIDENTE DE TRÁNSITO
# 3             ADULTOS       1.0  LESIONES EN ACCIDENTE DE TRÁNSITO
# 4             ADULTOS       1.0  LESIONES EN ACCIDENTE DE TRÁNSITO

# %% [markdown]
# ### HURTO RESIDENCIAS

# %%
# Hurto a residencias
url = 'https://www.policia.gov.co/sites/default/files/delitos-impacto/hurto_a_residencias_2018_1.xlsx'
df_hurto_residencias2024 = pd.read_excel(url, header=10)
df_hurto_residencias2024 = df_hurto_residencias2024.iloc[:-6]
df_hurto_residencias2024['TIPO_DELITO'] = 'HURTO RESIDENCIAS'
display(df_hurto_residencias2024.head())
# Out:
#   DEPARTAMENTO       MUNICIPIO  CODIGO DANE   ARMAS MEDIOS FECHA HECHO  \
# 0      BOLÍVAR         CALAMAR   13140000.0  ARMA DE FUEGO  2018-01-01
# 1       TOLIMA        PLANADAS   73555000.0  ARMA DE FUEGO  2018-01-01
# 2    ANTIOQUIA          ITAGUI    5360000.0   CONTUNDENTES  2018-01-01
# 3       ARAUCA            TAME   81794000.0   CONTUNDENTES  2018-01-01
# 4      BOLÍVAR  CARTAGENA (CT)   13001000.0   CONTUNDENTES  2018-01-01
#
#       GENERO AGRUPA EDAD PERSONA  CANTIDAD        TIPO_DELITO
# 0   FEMENINO             ADULTOS       1.0  HURTO RESIDENCIAS
# 1  MASCULINO             ADULTOS       1.0  HURTO RESIDENCIAS
# 2  MASCULINO             ADULTOS       1.0  HURTO RESIDENCIAS
# 3  MASCULINO             ADULTOS       1.0  HURTO RESIDENCIAS
# 4   FEMENINO             ADULTOS       1.0  HURTO RESIDENCIAS

# %% [markdown]
# ### HURTO AUTOMOTORES

# %%
# Hurto automotores
url = 'https://www.policia.gov.co/sites/default/files/delitos-impacto/hurto_automotores_2018_2.xlsx'
df_hurto_automotores2024 = pd.read_excel(url, header=10)
df_hurto_automotores2024 = df_hurto_automotores2024.iloc[:-6]
df_hurto_automotores2024['TIPO_DELITO'] = 'HURTO AUTOMOTORES'
display(df_hurto_automotores2024.head())
# Out:
#    DEPARTAMENTO         MUNICIPIO  CODIGO DANE   ARMAS MEDIOS FECHA HECHO  \
# 0         CAUCA      POPAYÁN (CT)   19001000.0  LLAVE MAESTRA  2018-01-01
# 1         CESAR   VALLEDUPAR (CT)   20001000.0  LLAVE MAESTRA  2018-01-01
# 2  CUNDINAMARCA  BOGOTÁ D.C. (CT)   11001000.0  LLAVE MAESTRA  2018-01-01
# 3         VALLE         CALI (CT)   76001000.0  LLAVE MAESTRA  2018-01-01
# 4         VALLE         CALI (CT)   76001000.0  LLAVE MAESTRA  2018-01-01
#
#       GENERO AGRUPA EDAD PERSONA  CANTIDAD        TIPO_DELITO
# 0  MASCULINO             ADULTOS       1.0  HURTO AUTOMOTORES
# 1  MASCULINO             ADULTOS       1.0  HURTO AUTOMOTORES
# 2   FEMENINO             ADULTOS       1.0  HURTO AUTOMOTORES
# 3   FEMENINO             ADULTOS       1.0  HURTO AUTOMOTORES
# 4  MASCULINO             ADULTOS       1.0  HURTO AUTOMOTORES

# %% [markdown]
# ### HURTO PERSONAS

# %%
# Hurto personas
url = 'https://www.policia.gov.co/sites/default/files/delitos-impacto/hurto_a_personas_2018_1.xlsx'
df_hurto_personas2024 = pd.read_excel(url, header=10)
df_hurto_personas2024 = df_hurto_personas2024.iloc[:-6]
df_hurto_personas2024['TIPO_DELITO'] = 'HURTO A PERSONAS'
display(df_hurto_personas2024.head())
# Out:
#   DEPARTAMENTO     MUNICIPIO  CODIGO DANE                 ARMAS MEDIOS  \
# 0     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 1     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 2     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 3     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 4     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
#
#   FECHA HECHO     GENERO AGRUPA EDAD PERSONA  CANTIDAD       TIPO_DELITO
# 0  2018-01-06  MASCULINO             ADULTOS       1.0  HURTO A PERSONAS
# 1  2018-02-17   FEMENINO             ADULTOS       1.0  HURTO A PERSONAS
# 2  2018-02-27  MASCULINO             ADULTOS       1.0  HURTO A PERSONAS
# 3  2018-03-08  MASCULINO             ADULTOS       1.0  HURTO A PERSONAS
# 4  2018-03-18  MASCULINO             ADULTOS       1.0  HURTO A PERSONAS

# %% [markdown]
# ### HURTO MOTOCICLETAS

# %%
# Hurto motocicletas
url = 'https://www.policia.gov.co/sites/default/files/delitos-impacto/hurto_motocicletas_2018_0.xlsx'
df_hurto_motos2024 = pd.read_excel(url, header=10)
df_hurto_motos2024 = df_hurto_motos2024.iloc[:-6]
df_hurto_motos2024['TIPO_DELITO'] = 'HURTO MOTOCICLETAS'
display(df_hurto_motos2024.head())
# Out:
#   DEPARTAMENTO          MUNICIPIO  CODIGO DANE                 ARMAS MEDIOS  \
# 0        CESAR    VALLEDUPAR (CT)   20001000.0  ARMA BLANCA / CORTOPUNZANTE
# 1        VALLE          CALI (CT)   76001000.0  ARMA BLANCA / CORTOPUNZANTE
# 2        VALLE            PALMIRA   76520000.0  ARMA BLANCA / CORTOPUNZANTE
# 3    ANTIOQUIA      MEDELLÍN (CT)    5001000.0                ARMA DE FUEGO
# 4    ATLÁNTICO  BARRANQUILLA (CT)    8001000.0                ARMA DE FUEGO
#
#   FECHA HECHO  CANTIDAD         TIPO_DELITO
# 0  2018-01-01       1.0  HURTO MOTOCICLETAS
# 1  2018-01-01       1.0  HURTO MOTOCICLETAS
# 2  2018-01-01       1.0  HURTO MOTOCICLETAS
# 3  2018-01-01       1.0  HURTO MOTOCICLETAS
# 4  2018-01-01       1.0  HURTO MOTOCICLETAS

# %% [markdown]
# ### ABIGEATO

# %%
# Abigeato
url = 'https://www.policia.gov.co/sites/default/files/delitos-impacto/abigeato_2018_2.xlsx'
df_hurto_ganado2024 = pd.read_excel(url, header=10)
df_hurto_ganado2024 = df_hurto_ganado2024.iloc[:-6]
df_hurto_ganado2024['TIPO_DELITO'] = 'HURTO CABEZAS GANADO'
display(df_hurto_ganado2024.head())
# Out:
#    DEPARTAMENTO        MUNICIPIO  CODIGO DANE                 ARMAS MEDIOS  \
# 0      CASANARE           OROCUÉ   85230000.0  ARMA BLANCA / CORTOPUNZANTE
# 1        ARAUCA             TAME   81794000.0          SIN EMPLEO DE ARMAS
# 2         CESAR  AGUSTÍN CODAZZI   20013000.0          SIN EMPLEO DE ARMAS
# 3  CUNDINAMARCA           MEDINA   25438000.0          SIN EMPLEO DE ARMAS
# 4  CUNDINAMARCA        ZIPAQUIRÁ   25899000.0          SIN EMPLEO DE ARMAS
#
#   FECHA HECHO     GENERO AGRUPA EDAD PERSONA  CANTIDAD           TIPO_DELITO
# 0  2018-01-01  MASCULINO             ADULTOS       1.0  HURTO CABEZAS GANADO
# 1  2018-01-01  MASCULINO             ADULTOS       1.0  HURTO CABEZAS GANADO
# 2  2018-01-01  MASCULINO             ADULTOS       1.0  HURTO CABEZAS GANADO
# 3  2018-01-01  MASCULINO             ADULTOS       1.0  HURTO CABEZAS GANADO
# 4  2018-01-01   FEMENINO             ADULTOS       1.0  HURTO CABEZAS GANADO

# %% [markdown]
# ### HURTO ENTIDADES FINANCIERAS

# %%
# Hurto entidades financieras
url = 'https://www.policia.gov.co/sites/default/files/delitos-impacto/hurto_a_entidades_financieras_2018_0.xlsx'
df_hurto_financiera2024 = pd.read_excel(url, header=10)
df_hurto_financiera2024 = df_hurto_financiera2024.iloc[:-6]
df_hurto_financiera2024['TIPO_DELITO'] = 'HURTO A ENTIDADES FINANCIERAS'
display(df_hurto_financiera2024.head())
# Out:
#    DEPARTAMENTO         MUNICIPIO  CODIGO DANE   ARMAS MEDIOS FECHA HECHO  \
# 0  CUNDINAMARCA  BOGOTÁ D.C. (CT)   11001000.0  ARMA DE FUEGO  2018-01-03
# 1  CUNDINAMARCA  BOGOTÁ D.C. (CT)   11001000.0  ARMA DE FUEGO  2018-01-10
# 2  CUNDINAMARCA  BOGOTÁ D.C. (CT)   11001000.0  ARMA DE FUEGO  2018-01-11
# 3  CUNDINAMARCA            SOACHA   25754000.0       PALANCAS  2018-01-13
# 4  CUNDINAMARCA  BOGOTÁ D.C. (CT)   11001000.0  ARMA DE FUEGO  2018-01-18
#
#    CANTIDAD                    TIPO_DELITO
# 0       1.0  HURTO A ENTIDADES FINANCIERAS
# 1       1.0  HURTO A ENTIDADES FINANCIERAS
# 2       1.0  HURTO A ENTIDADES FINANCIERAS
# 3       1.0  HURTO A ENTIDADES FINANCIERAS
# 4       1.0  HURTO A ENTIDADES FINANCIERAS

# %% [markdown]
# ### PIRATERÍA TERRESTRE

# %%
# Piratería terrestre
url = 'https://www.policia.gov.co/sites/default/files/delitos-impacto/pirateria_terrestre_2018_1.xlsx'
df_pirateria_terrestre2024 = pd.read_excel(url, header=10)
df_pirateria_terrestre2024 = df_pirateria_terrestre2024.iloc[:-6]
df_pirateria_terrestre2024['TIPO_DELITO'] = 'HURTO PIRATERÍA TERRESTRE'
display(df_pirateria_terrestre2024.head())
# Out:
#   DEPARTAMENTO   MUNICIPIO  CODIGO DANE                 ARMAS MEDIOS  \
# 0    ATLÁNTICO     SOLEDAD    8758000.0                ARMA DE FUEGO
# 1      QUINDÍO     CALARCA   63130000.0  ARMA BLANCA / CORTOPUNZANTE
# 2        CESAR    EL COPEY   20238000.0                ARMA DE FUEGO
# 3        CESAR  RÍO DE ORO   20614000.0                ARMA DE FUEGO
# 4      QUINDÍO     CALARCA   63130000.0                 ESCOPOLAMINA
#
#   FECHA HECHO     GENERO *AGRUPA EDAD PERSONA  CANTIDAD  \
# 0  2018-01-01  MASCULINO              ADULTOS       1.0
# 1  2018-01-04        NaN                  NaN       1.0
# 2  2018-01-05  MASCULINO              ADULTOS       1.0
# 3  2018-01-05  MASCULINO              ADULTOS       1.0
# 4  2018-01-05        NaN                  NaN       1.0
#
#                  TIPO_DELITO
# 0  HURTO PIRATERÍA TERRESTRE
# 1  HURTO PIRATERÍA TERRESTRE
# 2  HURTO PIRATERÍA TERRESTRE
# 3  HURTO PIRATERÍA TERRESTRE
# 4  HURTO PIRATERÍA TERRESTRE

# %% [markdown]
# ### HOMICIDIOS

# %%
# Homicidios
url = 'https://www.policia.gov.co/sites/default/files/delitos-impacto/Homicidio%20Intencional%202018.xlsx'
df_homicidio_intencional2024 = pd.read_excel(url, header=9)
df_homicidio_intencional2024 = df_homicidio_intencional2024.iloc[:-6]
df_homicidio_intencional2024['TIPO_DELITO'] = 'HOMICIDIO INTENCIONAL'
display(df_homicidio_intencional2024.head())
# Out:
#   ARMAS MEDIOS DEPARTAMENTO       MUNICIPIO  FECHA HECHO     GENERO  \
# 0     ALMOHADA    ANTIOQUIA   Medellín (CT)   20180818.0   FEMENINO
# 1     ALMOHADA    ANTIOQUIA   Puerto Berrío   20180207.0  MASCULINO
# 2     ALMOHADA      BOLÍVAR  Cartagena (CT)   20180515.0  MASCULINO
# 3     ALMOHADA        CAUCA         Miranda   20180617.0   FEMENINO
# 4     ALMOHADA        CHOCÓ      Bajo Baudó   20180312.0   FEMENINO
#
#   *AGRUPA EDAD PERSONA*  CODIGO DANE  CANTIDAD            TIPO_DELITO
# 0               ADULTOS    5001000.0       1.0  HOMICIDIO INTENCIONAL
# 1               ADULTOS    5579000.0       1.0  HOMICIDIO INTENCIONAL
# 2               ADULTOS   13001000.0       1.0  HOMICIDIO INTENCIONAL
# 3               ADULTOS   19455000.0       1.0  HOMICIDIO INTENCIONAL
# 4               MENORES   27077000.0       1.0  HOMICIDIO INTENCIONAL

# %% [markdown]
# ### LESIONES PERSONALES

# %%
# Lesiones personales
url = 'https://www.policia.gov.co/sites/default/files/delitos-impacto/lesiones_personales_2018_0.xlsx'
df_lesiones_personales2024 = pd.read_excel(url, header=10)
df_lesiones_personales2024 = df_lesiones_personales2024.iloc[:-6]
df_lesiones_personales2024['TIPO_DELITO'] = 'LESIONES PERSONALES'
display(df_lesiones_personales2024.head())
# Out:
#   DEPARTAMENTO     MUNICIPIO  CODIGO DANE ARMAS MEDIOS FECHA HECHO     GENERO  \
# 0     AMAZONAS  LETICIA (CT)   91001000.0        ACIDO  2018-01-01  MASCULINO
# 1    ANTIOQUIA     ABEJORRAL    5002000.0        ACIDO  2018-01-01  MASCULINO
# 2    ANTIOQUIA        AMALFI    5031000.0        ACIDO  2018-01-01  MASCULINO
# 3    ANTIOQUIA         ANDES    5034000.0        ACIDO  2018-01-01  MASCULINO
# 4    ANTIOQUIA         ANDES    5034000.0        ACIDO  2018-01-01  MASCULINO
#
#   AGRUPA EDAD PERSONA  CANTIDAD          TIPO_DELITO
# 0             ADULTOS       1.0  LESIONES PERSONALES
# 1             ADULTOS       1.0  LESIONES PERSONALES
# 2             ADULTOS       1.0  LESIONES PERSONALES
# 3        ADOLESCENTES       1.0  LESIONES PERSONALES
# 4             ADULTOS       4.0  LESIONES PERSONALES

# %% [markdown]
# ### DELITOS SEXUALES

# %%
# Delitos sexuales
url = 'https://www.policia.gov.co/sites/default/files/delitos-impacto/delitos_sexuales_2018_0.xlsx'
df_delitos_sexuales2024 = pd.read_excel(url, header=10)
df_delitos_sexuales2024 = df_delitos_sexuales2024.iloc[:-6]
df_delitos_sexuales2024['TIPO_DELITO'] = 'DELITOS SEXUALES'
display(df_delitos_sexuales2024.head())
# Out:
#   DEPARTAMENTO      MUNICIPIO  CODIGO DANE                 ARMAS MEDIOS  \
# 0    ANTIOQUIA      GUADALUPE    5315000.0  ARMA BLANCA / CORTOPUNZANTE
# 1    ANTIOQUIA  MEDELLÍN (CT)    5001000.0  ARMA BLANCA / CORTOPUNZANTE
# 2    ANTIOQUIA  MEDELLÍN (CT)    5001000.0  ARMA BLANCA / CORTOPUNZANTE
# 3    ANTIOQUIA  MEDELLÍN (CT)    5001000.0  ARMA BLANCA / CORTOPUNZANTE
# 4    ATLÁNTICO        MALAMBO    8433000.0  ARMA BLANCA / CORTOPUNZANTE
#
#   FECHA HECHO    GENERO AGRUPA EDAD PERSONA  CANTIDAD       TIPO_DELITO
# 0  2018-01-01  FEMENINO             MENORES       1.0  DELITOS SEXUALES
# 1  2018-01-01  FEMENINO        ADOLESCENTES       1.0  DELITOS SEXUALES
# 2  2018-01-01  FEMENINO             ADULTOS       1.0  DELITOS SEXUALES
# 3  2018-01-01  FEMENINO             MENORES       1.0  DELITOS SEXUALES
# 4  2018-01-01  FEMENINO             ADULTOS       1.0  DELITOS SEXUALES

# %% [markdown]
# ### TERRORISMO

# %%
# Terrorismo
url = 'https://www.policia.gov.co/sites/default/files/delitos-impacto/terrorismo_2018_2.xlsx'
df_terrorismo2024 = pd.read_excel(url, header=10)
df_terrorismo2024 = df_terrorismo2024.iloc[:-6]
df_terrorismo2024['TIPO_DELITO'] = 'TERRORISMO'
display(df_terrorismo2024.head())
# Out:
#   Departamento Municipio  CODIGO DANE                        ARMAS MEDIOS  \
# 0       ARAUCA  SARAVENA   81736000.0  ARTEFACTO EXPLOSIVO/CARGA DINAMITA
# 1       BOYACÁ    CUBARÁ   15223000.0  ARTEFACTO EXPLOSIVO/CARGA DINAMITA
# 2     CASANARE   AGUAZUL   85010000.0  ARTEFACTO EXPLOSIVO/CARGA DINAMITA
# 3       ARAUCA      TAME   81794000.0  ARTEFACTO EXPLOSIVO/CARGA DINAMITA
# 4       NARIÑO   MALLAMA   52435000.0  ARTEFACTO EXPLOSIVO/CARGA DINAMITA
#
#   FECHA HECHO  CANTIDAD TIPO_DELITO
# 0  2018-01-10       1.0  TERRORISMO
# 1  2018-01-10       1.0  TERRORISMO
# 2  2018-01-10       1.0  TERRORISMO
# 3  2018-01-12       1.0  TERRORISMO
# 4  2018-01-13       1.0  TERRORISMO

# %%
# Renombrar columna en df_amenazas2024
df_amenazas2024 = df_amenazas2024.rename(columns={'AGRUPA EDAD PERSONA': 'AGRUPA_EDAD_PERSONA'})
display(df_amenazas2024.head())
# Out:
#   DEPARTAMENTO     MUNICIPIO  CODIGO DANE                 ARMAS MEDIOS  \
# 0     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 1     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 2     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 3     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 4     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
#
#   FECHA HECHO     GENERO AGRUPA_EDAD_PERSONA  CANTIDAD TIPO_DELITO
# 0  2018-01-02  MASCULINO             ADULTOS       1.0    AMENAZAS
# 1  2018-01-20   FEMENINO             ADULTOS       1.0    AMENAZAS
# 2  2018-01-20  MASCULINO        ADOLESCENTES       1.0    AMENAZAS
# 3  2018-03-27  MASCULINO             ADULTOS       1.0    AMENAZAS
# 4  2018-03-30  MASCULINO             ADULTOS       1.0    AMENAZAS

# %%
# Renombrar columna en df_extorsion2024
df_extorsion2024 = df_extorsion2024.rename(columns={'*AGRUPA EDAD PERSONA': 'AGRUPA_EDAD_PERSONA'})
display(df_extorsion2024.head())
# Out:
#   DEPARTAMENTO MUNICIPIO  CODIGO DANE     ARMAS MEDIOS FECHA HECHO     GENERO  \
# 0    ANTIOQUIA     ANORÍ    5040000.0  CARTA EXTORSIVA  2018-06-17  MASCULINO
# 1    ANTIOQUIA     ANORÍ    5040000.0  CARTA EXTORSIVA  2018-10-15  MASCULINO
# 2    ANTIOQUIA     BELLO    5088000.0  CARTA EXTORSIVA  2018-06-12  MASCULINO
# 3    ANTIOQUIA     BELLO    5088000.0  CARTA EXTORSIVA  2018-09-13  MASCULINO
# 4    ANTIOQUIA     BELLO    5088000.0  CARTA EXTORSIVA  2018-12-23  MASCULINO
#
#   AGRUPA_EDAD_PERSONA  CANTIDAD TIPO_DELITO
# 0             ADULTOS       1.0   EXTORSIÓN
# 1             ADULTOS       1.0   EXTORSIÓN
# 2             ADULTOS       1.0   EXTORSIÓN
# 3             ADULTOS       1.0   EXTORSIÓN
# 4             ADULTOS       1.0   EXTORSIÓN

# %%
# Renombrar columna en df_lesiones_transito2024
df_lesiones_transito2024 = df_lesiones_transito2024.rename(columns={'AGRUPA EDAD PERSONA': 'AGRUPA_EDAD_PERSONA'})
display(df_lesiones_transito2024.head())
# Out:
#    DEPARTAMENTO   MUNICIPIO  CODIGO DANE FECHA HECHO     GENERO  \
# 0  CUNDINAMARCA   ZIPAQUIRÁ   25899000.0  2018-01-01   FEMENINO
# 1         CAUCA     CALDONO   19137000.0  2018-01-01  MASCULINO
# 2     ANTIOQUIA       BELLO    5088000.0  2018-01-01   FEMENINO
# 3     ANTIOQUIA  COPACABANA    5212000.0  2018-01-01   FEMENINO
# 4     ANTIOQUIA  COPACABANA    5212000.0  2018-01-01  MASCULINO
#
#   AGRUPA_EDAD_PERSONA  CANTIDAD                        TIPO_DELITO
# 0             ADULTOS       1.0  LESIONES EN ACCIDENTE DE TRÁNSITO
# 1             ADULTOS       1.0  LESIONES EN ACCIDENTE DE TRÁNSITO
# 2             ADULTOS       1.0  LESIONES EN ACCIDENTE DE TRÁNSITO
# 3             ADULTOS       1.0  LESIONES EN ACCIDENTE DE TRÁNSITO
# 4             ADULTOS       1.0  LESIONES EN ACCIDENTE DE TRÁNSITO

# %%
# Renombrar columna en df_hurto_residencias2024
df_hurto_residencias2024 = df_hurto_residencias2024.rename(columns={'AGRUPA EDAD PERSONA': 'AGRUPA_EDAD_PERSONA'})
display(df_hurto_residencias2024.head())
# Out:
#   DEPARTAMENTO       MUNICIPIO  CODIGO DANE   ARMAS MEDIOS FECHA HECHO  \
# 0      BOLÍVAR         CALAMAR   13140000.0  ARMA DE FUEGO  2018-01-01
# 1       TOLIMA        PLANADAS   73555000.0  ARMA DE FUEGO  2018-01-01
# 2    ANTIOQUIA          ITAGUI    5360000.0   CONTUNDENTES  2018-01-01
# 3       ARAUCA            TAME   81794000.0   CONTUNDENTES  2018-01-01
# 4      BOLÍVAR  CARTAGENA (CT)   13001000.0   CONTUNDENTES  2018-01-01
#
#       GENERO AGRUPA_EDAD_PERSONA  CANTIDAD        TIPO_DELITO
# 0   FEMENINO             ADULTOS       1.0  HURTO RESIDENCIAS
# 1  MASCULINO             ADULTOS       1.0  HURTO RESIDENCIAS
# 2  MASCULINO             ADULTOS       1.0  HURTO RESIDENCIAS
# 3  MASCULINO             ADULTOS       1.0  HURTO RESIDENCIAS
# 4   FEMENINO             ADULTOS       1.0  HURTO RESIDENCIAS

# %%
# Renombrar columna en df_hurto_personas2024
df_hurto_personas2024 = df_hurto_personas2024.rename(columns={'AGRUPA EDAD PERSONA': 'AGRUPA_EDAD_PERSONA'})
display(df_hurto_personas2024.head())
# Out:
#   DEPARTAMENTO     MUNICIPIO  CODIGO DANE                 ARMAS MEDIOS  \
# 0     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 1     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 2     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 3     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 4     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
#
#   FECHA HECHO     GENERO AGRUPA_EDAD_PERSONA  CANTIDAD       TIPO_DELITO
# 0  2018-01-06  MASCULINO             ADULTOS       1.0  HURTO A PERSONAS
# 1  2018-02-17   FEMENINO             ADULTOS       1.0  HURTO A PERSONAS
# 2  2018-02-27  MASCULINO             ADULTOS       1.0  HURTO A PERSONAS
# 3  2018-03-08  MASCULINO             ADULTOS       1.0  HURTO A PERSONAS
# 4  2018-03-18  MASCULINO             ADULTOS       1.0  HURTO A PERSONAS

# %%
# Renombrar columna en df_hurto_ganado2024
df_hurto_ganado2024 = df_hurto_ganado2024.rename(columns={'AGRUPA EDAD PERSONA': 'AGRUPA_EDAD_PERSONA'})
display(df_hurto_ganado2024.head())
# Out:
#    DEPARTAMENTO        MUNICIPIO  CODIGO DANE                 ARMAS MEDIOS  \
# 0      CASANARE           OROCUÉ   85230000.0  ARMA BLANCA / CORTOPUNZANTE
# 1        ARAUCA             TAME   81794000.0          SIN EMPLEO DE ARMAS
# 2         CESAR  AGUSTÍN CODAZZI   20013000.0          SIN EMPLEO DE ARMAS
# 3  CUNDINAMARCA           MEDINA   25438000.0          SIN EMPLEO DE ARMAS
# 4  CUNDINAMARCA        ZIPAQUIRÁ   25899000.0          SIN EMPLEO DE ARMAS
#
#   FECHA HECHO     GENERO AGRUPA_EDAD_PERSONA  CANTIDAD           TIPO_DELITO
# 0  2018-01-01  MASCULINO             ADULTOS       1.0  HURTO CABEZAS GANADO
# 1  2018-01-01  MASCULINO             ADULTOS       1.0  HURTO CABEZAS GANADO
# 2  2018-01-01  MASCULINO             ADULTOS       1.0  HURTO CABEZAS GANADO
# 3  2018-01-01  MASCULINO             ADULTOS       1.0  HURTO CABEZAS GANADO
# 4  2018-01-01   FEMENINO             ADULTOS       1.0  HURTO CABEZAS GANADO

# %%
# Renombrar columna en df_homicidio_intencional2024
df_homicidio_intencional2024 = df_homicidio_intencional2024.rename(columns={'*AGRUPA EDAD PERSONA*': 'AGRUPA_EDAD_PERSONA'})
display(df_homicidio_intencional2024.head())
# Out:
#   ARMAS MEDIOS DEPARTAMENTO       MUNICIPIO  FECHA HECHO     GENERO  \
# 0     ALMOHADA    ANTIOQUIA   Medellín (CT)   20180818.0   FEMENINO
# 1     ALMOHADA    ANTIOQUIA   Puerto Berrío   20180207.0  MASCULINO
# 2     ALMOHADA      BOLÍVAR  Cartagena (CT)   20180515.0  MASCULINO
# 3     ALMOHADA        CAUCA         Miranda   20180617.0   FEMENINO
# 4     ALMOHADA        CHOCÓ      Bajo Baudó   20180312.0   FEMENINO
#
#   AGRUPA_EDAD_PERSONA  CODIGO DANE  CANTIDAD            TIPO_DELITO
# 0             ADULTOS    5001000.0       1.0  HOMICIDIO INTENCIONAL
# 1             ADULTOS    5579000.0       1.0  HOMICIDIO INTENCIONAL
# 2             ADULTOS   13001000.0       1.0  HOMICIDIO INTENCIONAL
# 3             ADULTOS   19455000.0       1.0  HOMICIDIO INTENCIONAL
# 4             MENORES   27077000.0       1.0  HOMICIDIO INTENCIONAL

# %%
# Renombrar columna en df_homicidio_intencional2024
df_delitos_sexuales2024 = df_delitos_sexuales2024.rename(columns={'AGRUPA EDAD PERSONA': 'AGRUPA_EDAD_PERSONA'})
display(df_delitos_sexuales2024.head())
# Out:
#   DEPARTAMENTO      MUNICIPIO  CODIGO DANE                 ARMAS MEDIOS  \
# 0    ANTIOQUIA      GUADALUPE    5315000.0  ARMA BLANCA / CORTOPUNZANTE
# 1    ANTIOQUIA  MEDELLÍN (CT)    5001000.0  ARMA BLANCA / CORTOPUNZANTE
# 2    ANTIOQUIA  MEDELLÍN (CT)    5001000.0  ARMA BLANCA / CORTOPUNZANTE
# 3    ANTIOQUIA  MEDELLÍN (CT)    5001000.0  ARMA BLANCA / CORTOPUNZANTE
# 4    ATLÁNTICO        MALAMBO    8433000.0  ARMA BLANCA / CORTOPUNZANTE
#
#   FECHA HECHO    GENERO AGRUPA_EDAD_PERSONA  CANTIDAD       TIPO_DELITO
# 0  2018-01-01  FEMENINO             MENORES       1.0  DELITOS SEXUALES
# 1  2018-01-01  FEMENINO        ADOLESCENTES       1.0  DELITOS SEXUALES
# 2  2018-01-01  FEMENINO             ADULTOS       1.0  DELITOS SEXUALES
# 3  2018-01-01  FEMENINO             MENORES       1.0  DELITOS SEXUALES
# 4  2018-01-01  FEMENINO             ADULTOS       1.0  DELITOS SEXUALES

# %%
# Renombrar columna en df_homicidio_intencional2024
df_lesiones_personales2024 = df_lesiones_personales2024 .rename(columns={'AGRUPA EDAD PERSONA': 'AGRUPA_EDAD_PERSONA'})
display(df_lesiones_personales2024.head())
# Out:
#   DEPARTAMENTO     MUNICIPIO  CODIGO DANE ARMAS MEDIOS FECHA HECHO     GENERO  \
# 0     AMAZONAS  LETICIA (CT)   91001000.0        ACIDO  2018-01-01  MASCULINO
# 1    ANTIOQUIA     ABEJORRAL    5002000.0        ACIDO  2018-01-01  MASCULINO
# 2    ANTIOQUIA        AMALFI    5031000.0        ACIDO  2018-01-01  MASCULINO
# 3    ANTIOQUIA         ANDES    5034000.0        ACIDO  2018-01-01  MASCULINO
# 4    ANTIOQUIA         ANDES    5034000.0        ACIDO  2018-01-01  MASCULINO
#
#   AGRUPA_EDAD_PERSONA  CANTIDAD          TIPO_DELITO
# 0             ADULTOS       1.0  LESIONES PERSONALES
# 1             ADULTOS       1.0  LESIONES PERSONALES
# 2             ADULTOS       1.0  LESIONES PERSONALES
# 3        ADOLESCENTES       1.0  LESIONES PERSONALES
# 4             ADULTOS       4.0  LESIONES PERSONALES

# %%
# Renombrar columna en df_homicidio_intencional2024
df_pirateria_terrestre2024 = df_pirateria_terrestre2024 .rename(columns={'*AGRUPA EDAD PERSONA': 'AGRUPA_EDAD_PERSONA'})
display(df_pirateria_terrestre2024.head())
# Out:
#   DEPARTAMENTO   MUNICIPIO  CODIGO DANE                 ARMAS MEDIOS  \
# 0    ATLÁNTICO     SOLEDAD    8758000.0                ARMA DE FUEGO
# 1      QUINDÍO     CALARCA   63130000.0  ARMA BLANCA / CORTOPUNZANTE
# 2        CESAR    EL COPEY   20238000.0                ARMA DE FUEGO
# 3        CESAR  RÍO DE ORO   20614000.0                ARMA DE FUEGO
# 4      QUINDÍO     CALARCA   63130000.0                 ESCOPOLAMINA
#
#   FECHA HECHO     GENERO AGRUPA_EDAD_PERSONA  CANTIDAD  \
# 0  2018-01-01  MASCULINO             ADULTOS       1.0
# 1  2018-01-04        NaN                 NaN       1.0
# 2  2018-01-05  MASCULINO             ADULTOS       1.0
# 3  2018-01-05  MASCULINO             ADULTOS       1.0
# 4  2018-01-05        NaN                 NaN       1.0
#
#                  TIPO_DELITO
# 0  HURTO PIRATERÍA TERRESTRE
# 1  HURTO PIRATERÍA TERRESTRE
# 2  HURTO PIRATERÍA TERRESTRE
# 3  HURTO PIRATERÍA TERRESTRE
# 4  HURTO PIRATERÍA TERRESTRE

# %%
# Renombrar columna en df_homicidio_intencional2024
df_hurto_automotores2024 = df_hurto_automotores2024 .rename(columns={'AGRUPA EDAD PERSONA': 'AGRUPA_EDAD_PERSONA'})
display(df_hurto_automotores2024.head())
# Out:
#    DEPARTAMENTO         MUNICIPIO  CODIGO DANE   ARMAS MEDIOS FECHA HECHO  \
# 0         CAUCA      POPAYÁN (CT)   19001000.0  LLAVE MAESTRA  2018-01-01
# 1         CESAR   VALLEDUPAR (CT)   20001000.0  LLAVE MAESTRA  2018-01-01
# 2  CUNDINAMARCA  BOGOTÁ D.C. (CT)   11001000.0  LLAVE MAESTRA  2018-01-01
# 3         VALLE         CALI (CT)   76001000.0  LLAVE MAESTRA  2018-01-01
# 4         VALLE         CALI (CT)   76001000.0  LLAVE MAESTRA  2018-01-01
#
#       GENERO AGRUPA_EDAD_PERSONA  CANTIDAD        TIPO_DELITO
# 0  MASCULINO             ADULTOS       1.0  HURTO AUTOMOTORES
# 1  MASCULINO             ADULTOS       1.0  HURTO AUTOMOTORES
# 2   FEMENINO             ADULTOS       1.0  HURTO AUTOMOTORES
# 3   FEMENINO             ADULTOS       1.0  HURTO AUTOMOTORES
# 4  MASCULINO             ADULTOS       1.0  HURTO AUTOMOTORES

# %%
# Renombrar columna en df_homicidio_intencional2024
df_secuestro2024 = df_secuestro2024 .rename(columns={'AGRUPA EDAD PERSONA': 'AGRUPA_EDAD_PERSONA'})
display(df_secuestro2024.head())
# Out:
#    DEPARTAMENTO            MUNICIPIO  CODIGO DANE  \
# 0     ANTIOQUIA        MEDELLÍN (CT)    5001000.0
# 1        CALDAS              ANSERMA   17042000.0
# 2         CAUCA           VILLA RICA   19845000.0
# 3         CHOCÓ  EL CARMEN DE ATRATO   27245000.0
# 4  CUNDINAMARCA     BOGOTÁ D.C. (CT)   11001000.0
#
#                   ARMAS MEDIOS FECHA HECHO     GENERO AGRUPA_EDAD_PERSONA  \
# 0  ARMA BLANCA / CORTOPUNZANTE  2018-03-17  MASCULINO        ADOLESCENTES
# 1  ARMA BLANCA / CORTOPUNZANTE  2018-01-07   FEMENINO             ADULTOS
# 2  ARMA BLANCA / CORTOPUNZANTE  2018-04-09  MASCULINO             ADULTOS
# 3  ARMA BLANCA / CORTOPUNZANTE  2018-01-26  MASCULINO             ADULTOS
# 4  ARMA BLANCA / CORTOPUNZANTE  2018-04-22  MASCULINO             MENORES
#
#              DESCRIPCION CONDUCTA  CANTIDAD TIPO_DELITO
# 0  ARTÍCULO 168. SECUESTRO SIMPLE       1.0   SECUESTRO
# 1  ARTÍCULO 168. SECUESTRO SIMPLE       1.0   SECUESTRO
# ...

# %%
# Renombrar columna en df_homicidio_intencional2024
df_violencia_intra2024 = df_violencia_intra2024 .rename(columns={'*AGRUPA EDAD PERSONA': 'AGRUPA_EDAD_PERSONA'})
display(df_violencia_intra2024.head())
# Out:
#   DEPARTAMENTO     MUNICIPIO  CODIGO DANE                 ARMAS MEDIOS  \
# 0     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 1     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 2     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 3     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 4     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
#
#   FECHA HECHO     GENERO AGRUPA_EDAD_PERSONA  CANTIDAD  \
# 0  2018-02-11   FEMENINO             ADULTOS       1.0
# 1  2018-02-11  MASCULINO             ADULTOS       1.0
# 2  2018-03-02   FEMENINO             ADULTOS       1.0
# 3  2018-03-11  MASCULINO             ADULTOS       1.0
# 4  2018-05-27  MASCULINO             ADULTOS       1.0
#
#                TIPO_DELITO
# 0  VIOLENCIA INTRAFAMILIAR
# 1  VIOLENCIA INTRAFAMILIAR
# 2  VIOLENCIA INTRAFAMILIAR
# 3  VIOLENCIA INTRAFAMILIAR
# 4  VIOLENCIA INTRAFAMILIAR

# %% [markdown]
# ### UNIÓN Y LIMPIEZA

# %%
# Lista de dataframes a concatenar
dfs_2024 = [
    df_amenazas2024,
    df_extorsion2024,
    df_lesiones_transito2024,
    df_violencia_intra2024,
    df_secuestro2024,
    df_hurto_residencias2024,
    df_hurto_automotores2024,
    df_hurto_personas2024,
    df_hurto_motos2024,
    df_hurto_ganado2024,
    df_hurto_financiera2024,
    df_pirateria_terrestre2024,
    df_lesiones_personales2024,
    df_delitos_sexuales2024
]

# Concatenar los dataframes
df_consolidado_2024 = pd.concat(dfs_2024, ignore_index=True)

# Mostrar las primeras filas y la información del nuevo dataframe
display(df_consolidado_2024.head())
display(df_consolidado_2024.info())
# Out:
#   DEPARTAMENTO     MUNICIPIO  CODIGO DANE                 ARMAS MEDIOS  \
# 0     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 1     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 2     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 3     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
# 4     AMAZONAS  LETICIA (CT)   91001000.0  ARMA BLANCA / CORTOPUNZANTE
#
#   FECHA HECHO     GENERO AGRUPA_EDAD_PERSONA  CANTIDAD TIPO_DELITO  \
# 0  2018-01-02  MASCULINO             ADULTOS       1.0    AMENAZAS
# 1  2018-01-20   FEMENINO             ADULTOS       1.0    AMENAZAS
# 2  2018-01-20  MASCULINO        ADOLESCENTES       1.0    AMENAZAS
# 3  2018-03-27  MASCULINO             ADULTOS       1.0    AMENAZAS
# 4  2018-03-30  MASCULINO             ADULTOS       1.0    AMENAZAS
#
#   DESCRIPCION CONDUCTA
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# ...

# %%
# Calcular la cantidad de valores faltantes por columna
missing_values = df_consolidado_2024.isnull().sum()

# Mostrar la tabla de valores faltantes
display(missing_values)
# Out:
# DEPARTAMENTO                 0
# MUNICIPIO                    1
# CODIGO DANE                  1
# ARMAS MEDIOS             30752
# FECHA HECHO                  0
# GENERO                   24227
# AGRUPA_EDAD_PERSONA      24227
# CANTIDAD                     0
# TIPO_DELITO                  0
# DESCRIPCION CONDUCTA    389230
# dtype: int64

# %%
print("Valores únicos en la columna 'ARMAS MEDIOS':")
display(df_consolidado_2024['ARMAS MEDIOS'].unique())
# Out:
# Valores únicos en la columna 'ARMAS MEDIOS':
# array(['ARMA BLANCA / CORTOPUNZANTE', 'ARMA DE FUEGO', 'CONTUNDENTES',
#        'ESCOPOLAMINA', 'NO REPORTADO', 'SIN EMPLEO DE ARMAS',
#        'CARTA EXTORSIVA', 'DIRECTA', 'LLAMADA TELEFONICA', 'MIXTA',
#        'REDES SOCIALES', nan, 'LLAVE MAESTRA', 'PALANCAS', 'JERINGA',
#        'PERRO', 'SUSTANCIAS TOXICAS', 'ACIDO',
#        'POLVORA(FUEGOS PIROTECNICOS)', 'QUIMICOS', 'VEHICULO',
#        'AGUA CALIENTE', 'COMBUSTIBLE', 'GRANADA DE MANO', 'MOTO',
#        'ARTEFACTO EXPLOSIVO/CARGA DINAMITA', 'MEDICAMENTOS',
#        'PRENDAS DE VESTIR', 'CINTAS/CINTURON', 'ALIMENTOS VENCIDOS',
#        'PAQUETE BOMBA', 'GASES', 'PAPA EXPLOSIVA', 'CILINDRO BOMBA',
#        'ALUCINOGENOS', 'MINA ANTIPERSONA', 'ARTEFACTO INCENDIARIO',
#        'BOLSA PLASTICA', 'ALMOHADA', 'LICOR ADULTERADO', 'VENENO',
#        'ESPOSAS'], dtype=object)

# %%
print("Valores únicos en la columna 'DEPARTAMENTO':")
display(df_consolidado_2024['DEPARTAMENTO'].unique())
# Out:
# Valores únicos en la columna 'DEPARTAMENTO':
# array(['AMAZONAS', 'ANTIOQUIA', 'ARAUCA', 'ATLÁNTICO', 'BOLÍVAR',
#        'BOYACÁ', 'CALDAS', 'CAQUETÁ', 'CASANARE', 'CAUCA', 'CESAR',
#        'CHOCÓ', 'CÓRDOBA', 'CUNDINAMARCA', 'GUAINÍA', 'GUAJIRA',
#        'GUAVIARE', 'HUILA', 'MAGDALENA', 'META', 'NARIÑO',
#        'NORTE DE SANTANDER', 'PUTUMAYO', 'QUINDÍO', 'RISARALDA',
#        'SAN ANDRÉS', 'SANTANDER', 'SUCRE', 'TOLIMA', 'VALLE', 'VAUPÉS',
#        'VICHADA'], dtype=object)

# %%
print("Valores únicos en la columna 'MUNICIPIO':")
display(df_consolidado_2024['MUNICIPIO'].nunique())
# Out:
# Valores únicos en la columna 'MUNICIPIO':
# 1021

# %%
print("Valores únicos en la columna 'GENERO':")
display(df_consolidado_2024['GENERO'].unique())
# Out:
# Valores únicos en la columna 'GENERO':
# array(['MASCULINO', 'FEMENINO', nan], dtype=object)

# %%
print("Valores únicos en la columna 'TIPO_DELITO':")
display(df_consolidado_2024['TIPO_DELITO'].unique())
# Out:
# Valores únicos en la columna 'TIPO_DELITO':
# array(['AMENAZAS', 'EXTORSIÓN', 'LESIONES EN ACCIDENTE DE TRÁNSITO',
#        'VIOLENCIA INTRAFAMILIAR', 'SECUESTRO', 'HURTO RESIDENCIAS',
#        'HURTO AUTOMOTORES', 'HURTO A PERSONAS', 'HURTO MOTOCICLETAS',
#        'HURTO CABEZAS GANADO', 'HURTO A ENTIDADES FINANCIERAS',
#        'HURTO PIRATERÍA TERRESTRE', 'LESIONES PERSONALES',
#        'DELITOS SEXUALES'], dtype=object)

# %%
import numpy as np

# Replace None with NaN in the 'GENERO' column
df_consolidado_2024['GENERO'] = df_consolidado_2024['GENERO'].replace({None: np.nan})

# Display unique values in 'GENERO' to verify the change
print("Valores únicos en la columna 'GENERO' después de la conversión:")
display(df_consolidado_2024['GENERO'].unique())
# Out:
# Valores únicos en la columna 'GENERO' después de la conversión:
# array(['MASCULINO', 'FEMENINO', nan], dtype=object)

# %%
import numpy as np

# Replace '-' with NaN in the 'GENERO' column
df_consolidado_2024['GENERO'] = df_consolidado_2024['GENERO'].replace({'-': np.nan})

# Display unique values in 'GENERO' to verify the change
print("Valores únicos en la columna 'GENERO' después de reemplazar '-':")
display(df_consolidado_2024['GENERO'].unique())
# Out:
# Valores únicos en la columna 'GENERO' después de reemplazar '-':
# array(['MASCULINO', 'FEMENINO', nan], dtype=object)

# %%
# Remove '(CT)' and convert to uppercase in the 'MUNICIPIO' column
df_consolidado_2024['MUNICIPIO'] = df_consolidado_2024['MUNICIPIO'].str.replace(' \(CT\)', '', regex=True).str.upper()

# Display unique values or a sample to verify the changes
print("Valores únicos en la columna 'MUNICIPIO' después de la limpieza:")
display(df_consolidado_2024['MUNICIPIO'].unique())
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\('
# <>:2: SyntaxWarning: invalid escape sequence '\('
# C:\Users\kevin\AppData\Local\Temp\ipykernel_18284\1479232723.py:2: SyntaxWarning: invalid escape sequence '\('
#   df_consolidado_2024['MUNICIPIO'] = df_consolidado_2024['MUNICIPIO'].str.replace(' \(CT\)', '', regex=True).str.upper()
# Valores únicos en la columna 'MUNICIPIO' después de la limpieza:
# array(['LETICIA', 'PUERTO NARIÑO', 'AMAGÁ', ..., 'ABRIAQUÍ',
#        'SAN JUANITO', 'JORDÁN'], shape=(1019,), dtype=object)

# %%
# Mostrar 5 registros aleatorios del dataframe consolidado
display(df_consolidado_2024.sample(10))
# Out:
#               DEPARTAMENTO     MUNICIPIO  CODIGO DANE  \
# 206858               VALLE  BUENAVENTURA   76109000.0
# 103696               VALLE          CALI   76001000.0
# 32122         CUNDINAMARCA   BOGOTÁ D.C.   11001000.0
# 28136               BOYACÁ          MUZO   15480000.0
# 312657  NORTE DE SANTANDER      PAMPLONA   54518000.0
# 94621         CUNDINAMARCA   BOGOTÁ D.C.   11001000.0
# 386637              NARIÑO       IPIALES   52356000.0
# 315353             CÓRDOBA      MONTERÍA   23001000.0
# 106701           ANTIOQUIA         YONDÓ    5893000.0
# 125203             QUINDÍO       ARMENIA   63001000.0
#
#                        ARMAS MEDIOS FECHA HECHO     GENERO  \
# 206858                ARMA DE FUEGO  2018-01-29   FEMENINO
# 103696                 CONTUNDENTES  2018-07-01  MASCULINO
# 32122           SIN EMPLEO DE ARMAS  2018-06-14  MASCULINO
# 28136           SIN EMPLEO DE ARMAS  2018-04-22  MASCULINO
# 312657  ARMA BLANCA / CORTOPUNZANTE  2018-05-26  MASCULINO
# ...

# %%
# Agrupar por tipo de delito y sumar la cantidad
delito_counts = df_consolidado_2024.groupby('TIPO_DELITO')['CANTIDAD'].sum().sort_values(ascending=False)

# Crear el gráfico de barras
plt.figure(figsize=(12, 6))
delito_counts.plot(kind='bar')
plt.title('Cantidad total de delitos por tipo en 2024')
plt.xlabel('Tipo de Delito')
plt.ylabel('Cantidad')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Convertir la columna 'FECHA HECHO' a datetime objects
df_consolidado_2024['FECHA HECHO'] = pd.to_datetime(df_consolidado_2024['FECHA HECHO'], errors='coerce')

# Display the info of the dataframe to verify the change
display(df_consolidado_2024.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389385 entries, 0 to 389384
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   DEPARTAMENTO          389385 non-null  object
#  1   MUNICIPIO             389384 non-null  object
#  2   CODIGO DANE           389384 non-null  float64
#  3   ARMAS MEDIOS          358633 non-null  object
#  4   FECHA HECHO           389385 non-null  datetime64[ns]
#  5   GENERO                365158 non-null  object
#  6   AGRUPA_EDAD_PERSONA   365158 non-null  object
#  7   CANTIDAD              389385 non-null  float64
#  8   TIPO_DELITO           389385 non-null  object
#  9   DESCRIPCION CONDUCTA  155 non-null     object
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 29.7+ MB
# None

# %% [markdown]
# Descargar una copia:

# %%
# Guardar el DataFrame como archivo CSV
df_consolidado_2024.to_csv('df_consolidado_2018.csv', index=False)
print("El DataFrame se ha guardado como 'df_consolidado_2024.csv'")
# Out:
# El DataFrame se ha guardado como 'df_consolidado_2024.csv'

# %%
from google.colab import files

# Descargar el archivo CSV
files.download('df_consolidado_2024.csv')
